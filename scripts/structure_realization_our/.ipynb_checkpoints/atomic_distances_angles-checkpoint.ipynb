# %%
import numpy as np
from get_coords import get_coords

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Building the functions - using just one domain 16pkA01

# %%
coords = get_coords('16pkA01')
coords
# Out:
# array([[5, 'GLU', 'E', ..., -15.953, 21.156, 16.122],
#        [5, 'GLU', 'E', ..., -15.944, 19.956, 15.229],
#        [5, 'GLU', 'E', ..., -16.724, 20.23, 13.94],
#        ...,
#        [192, 'LEU', 'L', ..., -6.902, 31.661, 16.767],
#        [192, 'LEU', 'L', ..., -5.748, 32.421, 16.114],
#        [192, 'LEU', 'L', ..., -7.745, 30.979, 15.701]], dtype=object)

# %% [markdown]
# ## What are the distances between neigboring atoms? What about same atoms?
# `C-N` `N-CA` `CA-C` `CA-CB`
#
# `C--C` `CA--CA` `N--N`

# %%
v = np.array([list(i) for i in coords if i[3] in ['N', 'C']])
v
# Out:
# array([['5', 'GLU', 'E', ..., '-15.953', '21.156', '16.122'],
#        ['5', 'GLU', 'E', ..., '-14.514', '19.536', '14.879'],
#        ['6', 'LYS', 'K', ..., '-13.659', '20.505', '14.561'],
#        ...,
#        ['191', 'TYR', 'Y', ..., '-7.24', '30.063', '18.559'],
#        ['192', 'LEU', 'L', ..., '-6.403', '30.676', '17.731'],
#        ['192', 'LEU', 'L', ..., '-7.745', '30.979', '15.701']],
#       dtype='<U21')

# %%
def compute_dist(coords, atom1, atom2):
    dist_vec = []
    
    # filter 
    c = np.array([list(i) for i in coords if i[3] in [atom1, atom2]])
    
    if atom1 == atom2:
        for i in range(len(c) - 1):
            if c[i + 1, 0].astype(np.int) - c[i, 0].astype(np.int) == 1:
                a1, a2 = c[i, 4:].astype(np.float), c[i + 1, 4:].astype(np.float)

                #if atom1 == 'CB' and c[i + 1, 0].astype(np.int) - c[i, 0].astype(np.int) > 1:
                #    pass
                #else:
                    #dist_vec.append(np.sqrt(sum((a1 - a2)**2)))
                dist_vec.append(np.sqrt(sum((a1 - a2)**2)))
    else:
        it = 0
        for i in range(len(c)//2 - 1):
            # I want the length of the bond between C-N, not their distance within residue
            if (atom1 == 'C' and atom2 == 'N') or (atom1 == 'N' and atom2 == 'C'):
                if c[it + 1, 0].astype(np.int) - c[it, 0].astype(np.int) == 1:
                    a1, a2 = c[it + 2, 4:].astype(np.float), c[it + 1, 4:].astype(np.float)
                    dist_vec.append(np.sqrt(sum((a1 - a2)**2)))
                    it += 2
                else:
                    it += 1
                    
            elif (atom1 == 'CA' and atom2 == 'CB') or (atom1 == 'CB' and atom2 == 'CA'):
                if c[it, 0] == c[it + 1, 0]:
                    a1, a2 = c[it, 4:].astype(np.float), c[it + 1, 4:].astype(np.float)
                    dist_vec.append(np.sqrt(sum((a1 - a2)**2)))
                    it += 2
                else:
                    it += 1
            else:
                if c[it + 1, 0].astype(np.int) - c[it, 0].astype(np.int) == 1:
                    a1, a2 = c[it, 4:].astype(np.float), c[it + 1, 4:].astype(np.float)
                    dist_vec.append(np.sqrt(sum((a1 - a2)**2)))
                    it += 2
                else:
                    it += 1
        
    return np.array(dist_vec)

# %%
fig, ax = plt.subplots(4, 4, figsize=(16, 16))

atoms = ['N', 'CA', 'CB', 'C']

for i in range(len(atoms)):
    for j in range(len(atoms)):
        if (atoms[i] == 'CB' and atoms[j] not in ['CA', 'CB']) or (atoms[j] == 'CB' and atoms[i] not in ['CA', 'CB']):
            ax[i, j].set_title(f'{atoms[i]} - {atoms[j]}', fontsize=15)
            
        elif atoms[i] == atoms[j] and atoms[i] != 'CA':
            ax[i, j].set_title(f'{atoms[i]} - {atoms[j]}', fontsize=15)
        else:
            dist = compute_dist(coords, atoms[i], atoms[j])
            ax[i, j].hist(dist, bins=20)
            ax[i, j].axvline(np.mean(dist), c='red')
            ax[i, j].text(np.mean(dist), 5, f'{round(np.mean(dist), 2)}', c='orange', fontsize=15)
            ax[i, j].set_title(f'{atoms[i]} - {atoms[j]}', fontsize=15)

# %% [markdown]
# ## What are the angles (not torsion)?
# `C-N-CA` `N-CA-C` `CA-C-N`

# %%
def compute_angles(coords, angle_atoms):
    angle_vec = []
    
    # filter
    if angle_atoms == ('C', 'CA', 'CB'):
        c = coords[coords[:, 2] != 'G']
        c = c[c[:, 3] != 'N']
        
        for i in range(len(c) - 3):
            if c[i, 3] == 'CA':
                if c[i, 0] == c[i+1, 0] == c[i+2, 0]:
                    a2, a3, a1 = c[i, 4:].astype(np.float), c[i+1, 4:].astype(np.float), c[i+2, 4:].astype(np.float)

                    v1, v2 = a2 - a1, a3 - a2            
                    v1_size, v2_size = np.sqrt(np.sum(v1**2)), np.sqrt(np.sum(v2**2))

                    angle = np.degrees(np.pi - np.arccos(np.sum(v1 * v2) / (v1_size * v2_size)))

                    angle_vec.append(angle)
        
    else:
        c = np.array([list(i) for i in coords if i[3] != 'CB'])
       
        for i in range(len(c) - 3):
            if c[i, 3] == angle_atoms[0]:
                a1, a2, a3 = c[i, 4:].astype(np.float), c[i+1, 4:].astype(np.float), c[i+2, 4:].astype(np.float)

                v1, v2 = a2 - a1, a3 - a2            
                v1_size, v2_size = np.sqrt(np.sum(v1**2)), np.sqrt(np.sum(v2**2))

                angle = np.degrees(np.pi - np.arccos(np.sum(v1 * v2) / (v1_size * v2_size)))

                angle_vec.append(angle)
    return angle_vec

# %%
fig, ax = plt.subplots(1, 4, figsize = (20, 5))

for i, a in enumerate([('N', 'CA', 'C'), ('CA', 'C', 'N'), ('C', 'N', 'CA'), ('C', 'CA', 'CB')]):
    angles = compute_angles(coords, a)
    ax[i].hist(angles, bins=20)
    ax[i].axvline(np.mean(angles), c='red')
    ax[i].text(np.mean(angles), 5, f'{round(np.mean(angles), 2)}', c='orange', fontsize=15)
    ax[i].set_title(f'{a[0]} - {a[1]} - {a[2]}', fontsize=15)

# %% [markdown]
# # Distributions using several proteins

# %%
def get_dist_angle_distributions(domain, dist_angle_list):
    try:
        coords = get_coords(domain)
    except:
        print(domain, 'Fuck it')
        return
    
    if coords is None:
        return
    # distances
    # N-CA, CA-CB, CA-C, C-N, CA-CA
    
    it = 0
    for (at1, at2) in [('N', 'CA'), ('CA', 'CB'), ('CA', 'C'), ('C', 'N'), ('CA', 'CA')]:
        dist = list(compute_dist(coords, at1, at2))
        dist_angle_list[it].extend(dist)
        it += 1
        
    # angles
    # N-CA-C, CA-C-N, C-N-CA
    for angle in [('N', 'CA', 'C'), ('CA', 'C', 'N'), ('C', 'N', 'CA'), ('C', 'CA', 'CB')]:
        ang = list(compute_angles(coords, angle))
        dist_angle_list[it].extend(ang)
        it += 1
        
    return dist_angle_list

# %%
# train set domains
train_domains = np.loadtxt('../../data/our_input/train_domains.csv', dtype='O')

# %%
dist_angle = [[], [], [], [], [], [], [], [], []]
dist_angle

np.random.seed(1618)
train_domains = np.random.permutation(train_domains)
for i in range(50):
    dalist = get_dist_angle_distributions(train_domains[i], dist_angle)
    if dalist is None:
        pass
    else:
        dist_angle = dalist
# Out:
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9013.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9069.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9108.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9131.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9178.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9552.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 16996.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 17024.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 17052.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 17059.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9663.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9670.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 9678.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 9685.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9690.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9737.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 9779.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 9856.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 6137.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 6196.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 6255.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 6308.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 6367.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 6514.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 6639.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 6761.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3945.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3967.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3989.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4196.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3297.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3341.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3369.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3486.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8752.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8784.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 10259.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 10341.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 10435.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 10530.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 7875.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 7959.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8001.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 8039.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 8041.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 8055.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8060.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8203.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8280.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 8408.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 8515.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 8655.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8799.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8800.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 8802.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 8803.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 8804.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8805.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8869.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8914.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 9015.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 9099.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 9149.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9665.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9788.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 9885.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 9912.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5977.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 6001.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 6026.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 6352.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8078.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8090.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8103.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 8115.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 8128.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 8140.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8152.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8307.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 8459.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 8631.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 8790.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 8949.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 20538.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 20563.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 20588.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 20798.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 14335.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 14367.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 14399.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 15745.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2103.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2188.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 2294.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4644.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4649.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 4654.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 4659.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4664.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4708.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 4771.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 4816.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 7115.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 7175.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 7263.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 7417.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5066.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 5110.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5154.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 5170.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8935.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9006.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 9071.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 9452.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 16051.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 16060.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 16069.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 16081.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 16105.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 16127.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 15018.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 15024.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 15030.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 15036.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 15042.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 15048.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 15059.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 15063.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 23019.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 23023.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 23025.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain E is discontinuous at line 23027.
#   warnings.warn(
# /home/tomasla/miniconda3/envs/thesis/lib/python3.8/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain F is discontinuous at line 23028.
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 5, figsize=(22, 4))

for i, atoms in enumerate(['NCA', 'CACB', 'CAC', 'CN', 'CACA']):
    ax[i].hist(dist_angle[i], bins = 50)
    ax[i].axvline(np.mean(dist_angle[i]), c='red')
    ax[i].text(-0.3 + (np.mean(dist_angle[i]) -  np.min(dist_angle[i]))/ (np.max(dist_angle[i]) - np.min(dist_angle[i])), 0.5, f'{round(np.mean(dist_angle[i]), 2)}', c='red', fontsize=15, transform=ax[i].transAxes)
    ax[i].text(-0.4 + (np.mean(dist_angle[i]) -  np.min(dist_angle[i]))/ (np.max(dist_angle[i]) - np.min(dist_angle[i])), 0.4, f'+-{round(np.std(dist_angle[i]), 4)}', c='red', fontsize=15, transform=ax[i].transAxes)
    #ax[i].text(np.mean(dist_angle[i]), 0, f'{round(np.mean(dist_angle[i]), 2)}', c='red', fontsize=25)
    ax[i].set_title(f'{atoms}', fontsize=15)
    #ax[i].set_xlim(1, 5)
plt.savefig('../../plots/structure_realization/inter_atom_distances.png', dpi = 200)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

for i, atoms in enumerate(['NCAC', 'CACN', 'CNCA']):
    ax[i].hist(dist_angle[5 + i], bins = 50)
    ax[i].axvline(np.mean(dist_angle[i + 5]), c='red')
    ax[i].text(-0.3 + (np.mean(dist_angle[i + 5]) -  np.min(dist_angle[i + 5]))/ (np.max(dist_angle[i + 5]) - np.min(dist_angle[i + 5])), 0.5, f'{round(np.mean(dist_angle[i + 5]), 2)}', c='red', fontsize=15, transform=ax[i].transAxes)
    ax[i].text(-0.35 + (np.mean(dist_angle[i + 5]) -  np.min(dist_angle[i + 5]))/ (np.max(dist_angle[i + 5]) - np.min(dist_angle[i + 5])), 0.4, f'+-{round(np.std(dist_angle[i + 5]), 4)}', c='red', fontsize=15, transform=ax[i].transAxes)
    #ax[i].text(np.mean(dist_angle[i]), 0, f'{round(np.mean(dist_angle[i]), 2)}', c='red', fontsize=25)
    ax[i].set_title(f'{atoms}', fontsize=15)
    #ax[i].set_xlim(1, 5)
plt.savefig('../../plots/structure_realization/inter_atom_angles.png', dpi = 200)
